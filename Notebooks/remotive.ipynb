# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Send a request to the Remotive API
url = "https://remotive.com/api/remote-jobs"
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Step 2: Convert JSON data to DataFrame
    data = response.json()
    jobs = data['jobs']
    df = pd.DataFrame(jobs)
    # Step 3: Display the DataFrame
    print(df.head())
    
    # Step 4: Save the DataFrame as a CSV file
    df.to_csv('remote_jobs.csv', index=False)
    
    # Optional: Plotting a simple graph (e.g., number of jobs per category)
    job_counts = df['category'].value_counts()
    job_counts.plot(kind='bar')
    plt.xlabel('Job Category')
    plt.ylabel('Number of Jobs')
    plt.title('Number of Remote Jobs per Category')
    plt.show()
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
#         id                                                url  \
# 0  1923232  https://remotive.com/remote-jobs/devops/site-r...
# 1  1921208  https://remotive.com/remote-jobs/hr/gaming-rec...
# 2  1921916  https://remotive.com/remote-jobs/devops/it-spe...
# 3  1921188  https://remotive.com/remote-jobs/data/business...
# 4  1923053  https://remotive.com/remote-jobs/data/senior-d...
#
#                                                title    company_name  \
# 0                          Site Reliability Engineer    Sticker Mule
# 1                                   Gaming Recruiter    Seedify.fund
# 2  IT Specialist - Vulnerability Management & Lif...  Avery Dennison
# 3          Business Intelligence Senior Data Analyst    True Classic
# 4                                Senior Data Analyst      Renew Home
#
#                             company_logo           category  \
# 0  https://remotive.com/job/1923232/logo  DevOps / Sysadmin
# 1  https://remotive.com/job/1921208/logo    Human Resources
# 2  https://remotive.com/job/1921916/logo  DevOps / Sysadmin
# 3  https://remotive.com/job/1921188/logo      Data Analysis
# 4  https://remotive.com/job/1923053/logo      Data Analysis
#
#                                                 tags   job_type  \
# 0  [AWS, docker, go, javascript, kubernetes, post...  full_time
# 1  [video, blockchain, research, game design, ATS...  full_time
# 2                             [information security]  full_time
# 3   [business intelligence, sql, data visualization]  full_time
# 4                  [python, sql, data visualization]  full_time
#
#       publication_date candidate_required_location                     salary  \
# 0  2024-07-09T14:59:19                   Worldwide                 $130k-$140
# 1  2024-07-09T14:51:42                     Vietnam
# 2  2024-07-09T14:51:35              Czech Republic  attractive salary package
# 3  2024-07-09T14:51:24                         USA
# 4  2024-07-09T14:51:24                         USA              $126k - $175k
#
#                                          description  \
# 0  <p style="line-height: calc(var(--lineHeightNo...
# 1  <div>AAA STUDIO EXPERIENCE ESSENTIAL!!!! </div...
# 2  <br><br><div class="h3">Company Description</d...
# 3  <p><strong>About Us:</strong></p>\n<p>Founded ...
# 4  <p><strong>Who We Are</strong></p><p>Renew Hom...
#
#                         company_logo_url
# 0  https://remotive.com/job/1923232/logo
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
